# %% [markdown]
# # Task Description #
#
# This task reinforces the objective of Module 1 which is to become familiar with the most important measures of
# performance and risk in Financial Investments.
#
# ### Instructions ###
# The student must:
# - Go cell by cell completing the coding assignments.
#
# Note: It's OK to consult the Module's materials, but try to think critically about each measurement, its construction technique and its interpretation

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define 3 to 5 tickers of stocks you want to download inside the list
tickers = []

# %%
# Download the stock prices using the function we have shown in the previous notebooks
data = pd.DataFrame()

# %%
# Calculate both the arithmetic returns and the logarithmic returns for these stocks

# Arithmetic
arithmetic_returns = data.copy()

# Logarithmic
logarithmic_returns = data.copy()

# %%
# Plot the time series of the cumulative returns

# Create Time Series
plt.figure(figsize=(10, 6))

# %%
# Show the average annualized returns of your stocks
mean_returns = logarithmic_returns.copy()

# Print them
print('')

# %%
# Show the annualized standard deviation of your stocks
std_returns = logarithmic_returns.copy()

# Print them
print('')

# %%
# Choose one of your stocks and graph the returns histogram: Is the distribution Normal?

# Create Histogram
plt.figure(figsize=(10, 6))

# %%
# Show the kurtosis of the stock of your choice
kurtosis = logarithmic_returns.copy()

# %%
# Based on your selected stocks, choice and download a benchmark to comparison
benchmark_ticker = ''

# Data
benchmark_data = pd.DataFrame()

# %%
# Plot the time series of the cumulative returns of your favorite stock vs. the benchmark

# Create Time Series
plt.figure(figsize=(10, 6))

# %%
# Calculate the Value at Risk (VaR) for the three stocks
confidence_interval = 0.95

# %%
# Calculate
tracking_error = _

print(tracking_error)
# Out:
# Figure(1000x600)

# %%
# Plot the Standard Deviation, the VaR and the Tracking Error
fig, ax = plt.subplots(figsize=(10, 6))

# %%
# Calculated the Risk Adjusted Returns
eff_ratio = _

print(eff_ratio)
# Out:
# Figure(1000x600)

# %%
# Using the Price Data, calculate the Max Drawdown
cum_max = _

print('')
