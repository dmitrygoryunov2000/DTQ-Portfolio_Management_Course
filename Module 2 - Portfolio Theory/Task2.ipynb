# %% [markdown]
# # Task Description #
#
# This task reinforces the objective of Module 2 which is to learn to build efficient portfolios taking advantage of
# the only free lunch in Finance which is diversification.
#
# ### Instructions ###
# The student must:
# - Go cell by cell completing the coding assignments
# - Construct a first portfolio using data that lives on the efficient frontier and is suitable for an investor
# with risk tolerance of 10%
#
# Note: It's OK to consult the Module's materials, but try to think critically about each concept, its construction technique and its interpretation

# %%
# Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Define 5 tickers of stocks you want to download inside the list
tickers = []

# %%
# Download the stock returns using the function we have shown in the previous notebooks
data = pd.DataFrame()

# %%
# Calculate the Covariance Matrix for the stocks
covariance_matrix = _ 

covariance_matrix
# Out:
# ''

# %%
# Calculate the Correlation Matrix for the stocks
correlation_matrix = _ 

correlation_matrix
# Out:
# ''

# %%
# Define 5 arrays of weights; you can include the Equal-Weighted Portfolio
weights_1 = []
weights_2 = []
weights_3 = []
weights_4 = []
weights_5 = []

# %%
# Create the Portfolios
portfolio_1 = _ 
portfolio_2 = _
portfolio_3 = _ 
portfolio_4 = _
portfolio_5 = _

# %%
# Create a Scatter Plot (X: Volatility, Y: Returns) for these portfolios
plt.figure(figsize=(10, 6))

# %%
# Calculate the Efficient Frontier using the functions we showed in past modules
efficient_frontier = _

# %%
# Plot the Efficient Frontier
plt.figure(figsize=(10, 6))

# %%
# Choose one of the random portfolios and calculate a pair portfolio in the efficient frontier.
efficient_portfolio = _

# %%
# Plot the new portfolio showing it is over the Efficient Frontier:
plt.figure(figsize=(10, 6))

# %%
# Calculate the Sharpe Ratios of your portfolios (you can create a DataFrame including all these portfolios)
sharpe_ratios = _

# %%
# Find the Tangent Portfolio using the functions we showed in past notebooks

# %%
# Plot the Capital Allocation Line and show the tangent point with the efficient frontier
plt.figure(figsize=(10, 6))

# %%
# Create a Portfolio over the CAL (you can use the Tangent Portfolio or add the Risk Free Rate to reduce or increase risk)
cal_portfolio = _

# %%
# Create a Rebalancing Strategy (using the functions we showed) varying the rebalancing frequency and compare returns

# %%
# Print the Analytics of these portfolios

# %%
# Plot the Time Series of these Portfolios
plt.figure(figsize=(10, 6))
