# %%
# Import the necessary libraries

# %% [markdown]
# # Task Description #
#
# This task is a mini-project where students must apply the knowledge from the past module. The objective is to create a multiple linear regression model using financial and economic data downloaded from Yahoo Finance or the Federal Reserve APIs (e.g., AAPL stock returns vs. a benchmark index, interest rates, exchange rates, annualized volatility, or returns of other stocks).
#
# ### Instructions ###
# The student must:
#
# 1) Formulate a hypothesis (Why are these variables being chosen?).
# 2) Estimate the regression coefficients.
# 3) Compute the $R^2$ and the Adjusted $R^2$, and compare them.
# 4) Conduct statistical significance tests (including joint significance).
# 5) Calculate the fitted values and residuals.
# 6) Perform at least three diagnostic tests on the residuals (e.g., are they normally distributed?).
#
# ### Extra Credit ###
# Students may receive additional credit if they:
#
# - Include at least two exploratory/pre-analysis plots (Scatter Plots, Box Plots, etc.).
# - Apply Weighted Least Squares (WLS).
# - Extend the analysis to a multivariate regression.
#
# This notebook must include the procedures and code, and it must be delivered to the professor via email.
